# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("merged_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.5+ MB

# %%
temp= df.loc[df['Order Date'] != 'Order Date']
temp
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address
# ...

# %%
# converting order date column into DateTime

df['Order Date'] = pd.to_datetime(df['Order Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 8.5+ MB

# %%
#adding a month column from order date column into dataframe

df['Month'] = df['Order Date'].dt.month_name()
df['Month']
# Out:
# 0             April
# 1             April
# 2             April
# 3             April
# 4             April
#             ...
# 185945    September
# 185946    September
# 185947    September
# 185948    September
# 185949    September
# Name: Month, Length: 185950, dtype: object

# %%
# What was the best month for sales? How much was earned that month?
#adding a calculated column for total sale value 


df['TSV'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month     TSV
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  April   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  April   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  April  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  April   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  April   11.99

# %%
result=df.groupby('Month')['TSV'].sum()
result
# Out:
# Month
# April        3390670.24
# August       2244467.88
# December     4613443.34
# February     2202022.42
# January      1822256.73
# July         2647775.76
# June         2577802.26
# March        2807100.38
# May          3152606.75
# November     3199603.20
# October      3736726.88
# September    2097560.13
# Name: TSV, dtype: float64

# %%
#plotting the data 

months = range(1,13)
plt.bar(months,result)
plt.xticks(months)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# which city sold most product

df['City'] = df['Purchase Address'].str.split(',',expand=True)[1]
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
df.groupby('City')['Quantity Ordered'].sum().sort_values()
# Out:
# City
#  Austin           11153
#  Portland         14053
#  Seattle          16553
#  Atlanta          16602
#  Dallas           16730
#  Boston           22528
#  New York City    27932
#  Los Angeles      33289
#  San Francisco    50239
# Name: Quantity Ordered, dtype: int64

# %%
#plotting the data
keys = [city for city, df1 in df.groupby(['City'])]

plt.bar(keys,df.groupby(['City']).sum()['TSV'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()
# Out:
# C:\Users\aamir\AppData\Local\Temp\ipykernel_16716\1433755931.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   keys = [city for city, df1 in df.groupby(['City'])]
# C:\Users\aamir\AppData\Local\Temp\ipykernel_16716\1433755931.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(keys,df.groupby(['City']).sum()['TSV'])

# %%
#what time should advertize to maximize sale


df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
df.groupby('Hour')['TSV'].sum().sort_values(ascending=False)
# Out:
# Hour
# 19    2412938.54
# 12    2316821.34
# 11    2300610.24
# 20    2281716.24
# 18    2219348.30
# 13    2155389.80
# 17    2129361.61
# 14    2083672.73
# 21    2042000.86
# 10    1944286.77
# 15    1941549.60
# 16    1904601.31
# 9     1639030.58
# 22    1607549.21
# 8     1192348.97
# 23    1179304.44
# 7      744854.12
# 0      713721.27
# 1      460866.88
# 6      448113.00
# 2      234851.44
# 5      230679.82
# 4      162661.01
# 3      145757.89
# Name: TSV, dtype: float64

# %%
keys = [pair for pair, df1 in df.groupby(['Hour'])]

plt.plot(keys, df.groupby(['Hour']).count())
plt.xticks(keys)
plt.grid()
plt.show()
# Out:
# C:\Users\aamir\AppData\Local\Temp\ipykernel_16716\2068297110.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   keys = [pair for pair, df1 in df.groupby(['Hour'])]

# %%
#what products are often sold together

# All Duplicate Order ID 
df1 = df[df['Order ID'].duplicated(keep=False)]
df1
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 17        176574                Google Phone                 1      600.00
# 18        176574        USB-C Charging Cable                 1       11.95
# 29        176585  Bose SoundSport Headphones                 1       99.99
# ...          ...                         ...               ...         ...
# 185893    259303       AA Batteries (4-pack)                 1        3.84
# 185904    259314            Wired Headphones                 1       11.99
# 185905    259314      AAA Batteries (4-pack)                 2        2.99
# 185941    259350                Google Phone                 1      600.00
# 185942    259350        USB-C Charging Cable                 1       11.95
#
# ...

# %%
#group different products with same orderid

df1['Grouped'] = df1.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
df1.head(10)
# Out:
# C:\Users\aamir\AppData\Local\Temp\ipykernel_16716\2872873958.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Grouped'] = df1.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#      Order ID                     Product  Quantity Ordered  Price Each  \
# 2      176560                Google Phone                 1      600.00
# 3      176560            Wired Headphones                 1       11.99
# 17     176574                Google Phone                 1      600.00
# 18     176574        USB-C Charging Cable                 1       11.95
# 29     176585  Bose SoundSport Headphones                 1       99.99
# 30     176585  Bose SoundSport Headphones                 1       99.99
# ...

# %%
df.groupby('Product')['Quantity Ordered'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>
